# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow 
import keras  
import os
import glob 
from skimage import io 
import random 
import numpy as np
import cv2
from os import listdir
from PIL import Image as PImage
from skimage import color
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

# %%
folder_dir = '/content/drive/MyDrive/letters'

# %%
from PIL import Image
img=Image.open('/content/drive/MyDrive/letters/E.jpg')
img.size
# Out:
# (417, 453)

# %%
plt.imshow(img)

# %%
img = img.resize((400, 400))

# %%
folder_dir = "/content/drive/MyDrive/letters"
for images in os.listdir(folder_dir):
 
    if (images.endswith(".jpg")):   
        image = imread('/content/drive/MyDrive/letters/', as_gray=True)
        #imshow(image)
        print(image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-20530f489105> in <module>
#       3
#       4     if (images.endswith(".jpg")):
# ----> 5         image = imread('/content/drive/MyDrive/letters/', as_gray=True)
#       6         #imshow(image)
#       7         print(image)
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# ...

# %%
def loadImages(path):
    # return array of images

    imagesList = listdir(path)
    loadedImages = []
    for image in imagesList:
        img = PImage.open(path + image)
        loadedImages.append(img)

    return loadedImages

path = "/content/drive/MyDrive/letters/"

# your images in an array
imgs = loadImages(path)

for img in imgs:
    # you can show every image
    print(img.size)
plt.imshow(img)
# Out:
# (417, 453)
# (337, 441)
# (361, 457)
# (461, 453)
# (593, 493)
# (337, 457)
# (369, 445)
# (329, 389)
# (381, 393)
# (313, 453)
# (333, 465)
# (397, 433)
# (417, 425)
# (393, 497)
# (513, 429)
# (401, 421)
# (421, 421)
# (353, 449)
# (369, 445)
# (357, 385)
# (417, 437)
# (389, 445)
# (365, 441)
# (357, 465)
# (397, 429)
# (373, 453)

# %%
for img in imgs:
    
    img = img.resize((400, 400))
    print(img.size)
    plt.imshow(img)
    imgGray = img.convert('1')
    plt.imshow(imgGray)
# Out:
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)
# (400, 400)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from skimage.io import imread, imshow

image = imread('/content/drive/MyDrive/letters/')
imshow(image)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-83c346761435> in <module>
#       5 from skimage.io import imread, imshow
#       6
# ----> 7 image = imread('/content/drive/MyDrive/letters/')
#       8 imshow(image)
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      46
#      47     with file_or_url_context(fname) as fname:
# ---> 48         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      49
#      50     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.7/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# ...

# %%
image.shape, image
# Out:
# ((453, 417),
#  array([[0.59185922, 0.59185922, 0.60362392, ..., 0.7300149 , 0.7300149 ,
#          0.73393647],
#         [0.58793765, 0.60754549, 0.6193102 , ..., 0.7300149 , 0.7300149 ,
#          0.7300149 ],
#         [0.58009451, 0.61538863, 0.62715333, ..., 0.72609333, 0.72609333,
#          0.72609333],
#         ...,
#         [0.60981529, 0.61373686, 0.61765843, ..., 0.70370275, 0.69978118,
#          0.70370275],
#         [0.60197216, 0.60589373, 0.60981529, ..., 0.70370275, 0.70370275,
#          0.70370275],
#         [0.60197216, 0.60197216, 0.60197216, ..., 0.70370275, 0.70370275,
#          0.70370275]]))

# %%
image = imread('/content/drive/MyDrive/letters/E.jpg', as_gray=True)
imshow(image)

# %%
import glob
cv_img = []
for img in glob.glob("/content/drive/MyDrive/letters/*.jpg"):
    n= cv2.imread(img,cv2.IMREAD_GRAYSCALE)
    print(n.size)
    resized_img = cv2.resize(n/255.0  , (250 , 250))
    print(resized_img)
    cv_img.append(n)
    print(n.shape)
    plt.imshow(n)
    # features = np.reshape(n, (453*417))
    # features.shape, features
# Out:
# 188901
# [[0.59322361 0.6102853  0.60201545 ... 0.72363145 0.72940858 0.73096315]
#  [0.59047059 0.62655073 0.59192988 ... 0.71894118 0.72462916 0.72520466]
#  [0.58839961 0.59940416 0.59568667 ... 0.72298039 0.72952157 0.72833725]
#  ...
#  [0.60538024 0.59596863 0.60505843 ... 0.70729412 0.71371788 0.70980392]
#  [0.60943677 0.61397205 0.60913725 ... 0.69889412 0.70280784 0.70179142]
#  [0.60053178 0.60318431 0.59949012 ... 0.70036863 0.7019576  0.70196078]]
# (453, 417)
# 148617
# [[0.70370196 0.70046275 0.70176604 ... 0.67228102 0.67474276 0.67800968]
#  [0.69401802 0.69384397 0.70094118 ... 0.67503129 0.68047843 0.67843137]
#  [0.69405624 0.69581176 0.7014051  ... 0.6711898  0.67504698 0.67191506]
#  ...
#  [0.7222131  0.72192157 0.72192157 ... 0.69290196 0.69494502 0.70443271]
#  [0.72931214 0.72883922 0.72883922 ... 0.68620008 0.68785015 0.69114193]
#  [0.73064915 0.72941176 0.72941176 ... 0.69574769 0.70233725 0.70933384]]
# (441, 337)
# ...

# %%
n.shape,n
# Out:
# ((453, 373, 3), array([[[186, 185, 181],
#          [186, 185, 181],
#          [186, 185, 181],
#          ...,
#          [196, 192, 187],
#          [196, 192, 187],
#          [196, 192, 187]],
#
#         [[186, 185, 181],
#          [186, 185, 181],
#          [186, 185, 181],
#          ...,
#          [197, 193, 188],
#          [198, 194, 189],
#          [198, 194, 189]],
#
#         [[186, 185, 181],
#          [186, 185, 181],
#          [186, 185, 181],
#          ...,
#          [197, 193, 188],
#          [198, 194, 189],
#          [199, 195, 190]],
#
#         ...,
#
#         [[186, 183, 175],
#          [184, 181, 173],
#          [185, 182, 174],
#          ...,
#          [182, 179, 171],
#          [185, 182, 174],
#          [188, 185, 177]],
#
#         [[185, 182, 174],
#          [184, 181, 173],
#          [185, 182, 174],
#          ...,
#          [185, 182, 174],
#          [188, 185, 177],
#          [190, 187, 179]],
#
#         [[184, 181, 173],
# ...
